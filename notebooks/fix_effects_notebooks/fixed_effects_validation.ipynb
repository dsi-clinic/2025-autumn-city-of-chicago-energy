# %% [markdown]
# # Fixed Effects Validation
#
# **Author:** Alejandro Orellana
#
# **Date:** Janurary 22, 2026
#
# **Data Source:** Chicago Energy Benchmarking Dataset (2014-2023) - City of Chicago Open Data Portal
#
# **Purpose:** Process of trying to validate the findings of fixed_effects.ipynb by adding more variables
#
# ## Section 1: Loading Data

# %%
from utils.data_utils import load_data
from utils.fix_effect_utils import (
    prepare_analysis,
    prepared_dataframe,
    run_sensitivity_models,
)
from utils.plot_utils import plot_fixed_effects_coefficients, plotting_FE_star_coef

panel_data = prepared_dataframe(load_data())
target_col = "Weather Normalized Site EUI (kBtu/sq ft)"
rating_col = "Chicago Energy Rating"
analysis_df = prepare_analysis(panel_data, target_col, rating_col)
analysis_df.head(3)
# Out:
# 2026-02-28 21:28:35,532 [INFO] generated new fontManager
# 2026-02-28 21:28:39,776 [INFO] ✅ COVID Impact Category assignment (with 'Other' group) complete.
# 2026-02-28 21:28:39,780 [INFO] Category counts:
# COVID Impact Category
# Other                   505
# Permanent              1813
# Stable/Increased       7470
# Temporary/Rebounded    1716
# ----------------------------------------
# DATA ANALYSIS PREP SUMMARY
# ----------------------------------------
# Initial Total Rows:        10240
# Initial Unique Buildings:  1280
# ----------------------------------------
# Rows with Future Change:   7681
# Unique Buildings Retained: 1280
# Unique Buildings Lost: 0
# ----------------------------------------
#        Data Year      ID                       Property Name  \
# 11603       2016  100001  presence smemc st elizabeth campus
# 2543        2017  100001  presence smemc st elizabeth campus
# 28282       2018  100001  presence smemc st elizabeth campus
#
#                         Address ZIP Code Community Area Primary Property Type  \
# 11603  1431 North Claremont Ave    60622      west town              hospital
# 2543   1431 North Claremont Ave    60622      west town              hospital
# 28282  1431 North Claremont Ave    60622      west town              hospital
#
#        Gross Floor Area - Buildings (sq ft)  Year Built  # of Buildings  ...  \
# 11603                              309056.0      1928.0             1.0  ...
# 2543                               309056.0      1928.0             1.0  ...
# 28282                              309056.0      1928.0             1.0  ...
#
#        COVID Impact Category  Effective Year Built  Time Built  Current_EUI  \
# 11603                  Other                1928.0   1920-1960        194.6
# 2543                   Other                1928.0   1920-1960        186.9
# 28282                  Other                1928.0   1920-1960        186.5
#
#        Next_Year_EUI  Future_Change_Raw  Future_Change  Rating_Numeric  \
# 11603          186.9               -7.7           -7.7             NaN
# 2543           186.5               -0.4           -0.4             NaN
# 28282            NaN                NaN            NaN             NaN
#
#        Rating_Cat  Post_Policy
# 11603        None            0
# 2543         None            0
# 28282        None            0
#
# [3 rows x 40 columns]

# %% [markdown]
# # Fixed Effect Validation
#
# The function below goes the base version (with only Star Score) and addtional variables. To see whether the outcomes come out consistent in trends and also whether the star score is as signifcant as the fixed_effect.ipynb has found

# %%
sensitivity_list = run_sensitivity_models(analysis_df)
# Out:
# Status               | Model Name
# ----------------------------------------
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Future_Change   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     29.96
# Date:                Sat, 28 Feb 2026   Prob (F-statistic):           7.58e-41
# Time:                        21:28:40   Log-Likelihood:                -20263.
# No. Observations:                5037   AIC:                         4.054e+04
# Df Residuals:                    5030   BIC:                         4.059e+04
# Df Model:                           6
# Covariance Type:                  HC1
# ====================================================================================================================
#                                                        coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                           -1.5974      0.196     -8.133      0.000      -1.982      -1.212
# C(Rating_Cat, Treatment(reference='0.0'))[T.1.0]    -4.7019      0.651     -7.221      0.000      -5.978      -3.426
# C(Rating_Cat, Treatment(reference='0.0'))[T.1.5]    -3.3661      0.784     -4.291      0.000      -4.904      -1.829
# C(Rating_Cat, Treatment(reference='0.0'))[T.2.0]    -0.8344      0.596     -1.400      0.162      -2.003       0.334
# C(Rating_Cat, Treatment(reference='0.0'))[T.2.5]     0.5472      0.497      1.102      0.271      -0.426       1.521
# C(Rating_Cat, Treatment(reference='0.0'))[T.3.0]     1.0107      0.480      2.107      0.035       0.070       1.951
# C(Rating_Cat, Treatment(reference='0.0'))[T.3.5]     1.5702      0.387      4.053      0.000       0.811       2.330
# C(Rating_Cat, Treatment(reference='0.0'))[T.4.0]     4.1769      0.316     13.203      0.000       3.557       4.797
# ==============================================================================
# Omnibus:                      674.884   Durbin-Watson:                   2.366
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7470.164
# Skew:                          -0.216   Prob(JB):                         0.00
# Kurtosis:                       8.950   Cond. No.                     1.51e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The smallest eigenvalue is 2.68e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Future_Change   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.057
# Method:                 Least Squares   F-statistic:                     26.66
# Date:                Sat, 28 Feb 2026   Prob (F-statistic):           8.11e-41
# Time:                        21:28:40   Log-Likelihood:                -20236.
# No. Observations:                5037   AIC:                         4.049e+04
# Df Residuals:                    5029   BIC:                         4.054e+04
# Df Model:                           7
# Covariance Type:                  HC1
# ====================================================================================================================
#                                                        coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                            1.0766      0.733      1.469      0.142      -0.360       2.513
# C(Rating_Cat, Treatment(reference='0.0'))[T.1.0]    -3.2012      0.721     -4.440      0.000      -4.614      -1.788
# C(Rating_Cat, Treatment(reference='0.0'))[T.1.5]    -2.6895      0.780     -3.446      0.001      -4.219      -1.160
# C(Rating_Cat, Treatment(reference='0.0'))[T.2.0]     0.0871      0.617      0.141      0.888      -1.122       1.296
# C(Rating_Cat, Treatment(reference='0.0'))[T.2.5]     0.7600      0.505      1.506      0.132      -0.229       1.749
# C(Rating_Cat, Treatment(reference='0.0'))[T.3.0]     1.1474      0.478      2.402      0.016       0.211       2.084
# C(Rating_Cat, Treatment(reference='0.0'))[T.3.5]     1.3406      0.386      3.475      0.001       0.584       2.097
# C(Rating_Cat, Treatment(reference='0.0'))[T.4.0]     3.6321      0.329     11.051      0.000       2.988       4.276
# Q('Current_EUI')                                    -0.0307      0.009     -3.398      0.001      -0.048      -0.013
# ==============================================================================
# Omnibus:                      625.422   Durbin-Watson:                   2.356
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7029.186
# Skew:                           0.044   Prob(JB):                         0.00
# Kurtosis:                       8.787   Cond. No.                     1.26e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The smallest eigenvalue is 3.58e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Future_Change   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     24.19
# Date:                Sat, 28 Feb 2026   Prob (F-statistic):           2.25e-53
# Time:                        21:28:40   Log-Likelihood:                -20202.
# No. Observations:                5037   AIC:                         4.043e+04
# Df Residuals:                    5025   BIC:                         4.051e+04
# Df Model:                          11
# Covariance Type:                  HC1
# ====================================================================================================================
#                                                        coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                            0.7661      0.627      1.222      0.222      -0.462       1.995
# C(Rating_Cat, Treatment(reference='0.0'))[T.1.0]    -3.2035      0.710     -4.509      0.000      -4.596      -1.811
# C(Rating_Cat, Treatment(reference='0.0'))[T.1.5]    -2.5205      0.774     -3.255      0.001      -4.038      -1.003
# C(Rating_Cat, Treatment(reference='0.0'))[T.2.0]     0.2279      0.604      0.377      0.706      -0.957       1.412
# C(Rating_Cat, Treatment(reference='0.0'))[T.2.5]     0.8000      0.497      1.608      0.108      -0.175       1.775
# C(Rating_Cat, Treatment(reference='0.0'))[T.3.0]     0.9931      0.474      2.094      0.036       0.063       1.923
# C(Rating_Cat, Treatment(reference='0.0'))[T.3.5]     1.0951      0.386      2.835      0.005       0.338       1.852
# C(Rating_Cat, Treatment(reference='0.0'))[T.4.0]     3.3741      0.337     10.020      0.000       2.714       4.034
# C(Q('Data Year'))[T.2017]                         3.322e-16   1.17e-16      2.846      0.004    1.03e-16    5.61e-16
# C(Q('Data Year'))[T.2018]                           -0.4335      0.473     -0.916      0.360      -1.361       0.494
# C(Q('Data Year'))[T.2019]                           -1.7000      0.523     -3.253      0.001      -2.724      -0.676
# C(Q('Data Year'))[T.2020]                            1.0332      0.376      2.748      0.006       0.296       1.770
# C(Q('Data Year'))[T.2021]                            2.7183      0.370      7.350      0.000       1.993       3.443
# C(Q('Data Year'))[T.2022]                           -0.8519      0.352     -2.421      0.015      -1.542      -0.162
# C(Q('Data Year'))[T.2023]                                 0          0        nan        nan           0           0
# Q('Current_EUI')                                    -0.0304      0.009     -3.377      0.001      -0.048      -0.013
# ==============================================================================
# Omnibus:                      637.716   Durbin-Watson:                   2.365
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7432.834
# Skew:                           0.038   Prob(JB):                         0.00
# Kurtosis:                       8.951   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Future_Change   R-squared:                       0.072
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     18.14
# Date:                Sat, 28 Feb 2026   Prob (F-statistic):           1.06e-50
# Time:                        21:28:40   Log-Likelihood:                -19867.
# No. Observations:                4950   AIC:                         3.977e+04
# Df Residuals:                    4934   BIC:                         3.987e+04
# Df Model:                          15
# Covariance Type:                  HC1
# ====================================================================================================================
#                                                        coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                            0.7630      0.737      1.036      0.300      -0.681       2.207
# C(Rating_Cat, Treatment(reference='0.0'))[T.1.0]    -3.3103      0.733     -4.519      0.000      -4.746      -1.875
# C(Rating_Cat, Treatment(reference='0.0'))[T.1.5]    -2.6226      0.798     -3.288      0.001      -4.186      -1.059
# C(Rating_Cat, Treatment(reference='0.0'))[T.2.0]     0.2264      0.613      0.369      0.712      -0.975       1.428
# C(Rating_Cat, Treatment(reference='0.0'))[T.2.5]     0.7936      0.500      1.589      0.112      -0.185       1.773
# C(Rating_Cat, Treatment(reference='0.0'))[T.3.0]     1.1167      0.481      2.322      0.020       0.174       2.059
# C(Rating_Cat, Treatment(reference='0.0'))[T.3.5]     1.1321      0.393      2.884      0.004       0.363       1.902
# C(Rating_Cat, Treatment(reference='0.0'))[T.4.0]     3.4273      0.348      9.856      0.000       2.746       4.109
# C(Q('Data Year'))[T.2017]                        -6.393e-17    1.8e-16     -0.356      0.722   -4.16e-16    2.88e-16
# C(Q('Data Year'))[T.2018]                           -0.3885      0.480     -0.810      0.418      -1.328       0.551
# C(Q('Data Year'))[T.2019]                           -1.9013      0.587     -3.237      0.001      -3.052      -0.750
# C(Q('Data Year'))[T.2020]                            1.0863      0.383      2.833      0.005       0.335       1.838
# C(Q('Data Year'))[T.2021]                            2.7676      0.381      7.259      0.000       2.020       3.515
# C(Q('Data Year'))[T.2022]                           -0.8009      0.364     -2.201      0.028      -1.514      -0.088
# C(Q('Data Year'))[T.2023]                        -3.295e-16   1.22e-16     -2.703      0.007   -5.68e-16   -9.06e-17
# C(Q('Time Built'))[T.1920-1960]                     -0.9527      0.660     -1.443      0.149      -2.247       0.342
# C(Q('Time Built'))[T.1960-1990]                      0.1395      0.649      0.215      0.830      -1.132       1.411
# C(Q('Time Built'))[T.1990-2010]                      0.0434      0.664      0.065      0.948      -1.258       1.345
# C(Q('Time Built'))[T.After 2010]                     0.3932      0.916      0.430      0.668      -1.401       2.188
# Q('Current_EUI')                                    -0.0294      0.009     -3.274      0.001      -0.047      -0.012
# ==============================================================================
# Omnibus:                      619.772   Durbin-Watson:                   2.357
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7084.211
# Skew:                           0.034   Prob(JB):                         0.00
# Kurtosis:                       8.860   Cond. No.                     1.30e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The smallest eigenvalue is 3.28e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /project/.venv/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /project/.venv/lib/python3.12/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 15, but rank is 12
#   warnings.warn('covariance of constraints does not have full '
# /project/.venv/lib/python3.12/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 19, but rank is 16
#   warnings.warn('covariance of constraints does not have full '

# %%
print(list(sensitivity_list.items())[0][0])
fig, ax = plot_fixed_effects_coefficients(list(sensitivity_list.items())[0][1])
# Out:
# 1. Base Star Rating

# %% [markdown]
# "1. Base Star Rating": "Future_Change ~ C(Rating_Cat, Treatment(reference='0.0'))"
# - This model shows a highly significant correlation where 1-Star buildings appear to improve by ~3 EUI units more than the baseline, showing the optimistic results of the fixed_effects.ipynb. However, this naive model assumes that only the stars drive the change, failing to account for why those buildings were inefficient in the first place.

# %%
print(list(sensitivity_list.items())[1][0])
fig, ax = plot_fixed_effects_coefficients(list(sensitivity_list.items())[1][1])
# Out:
# 2. +Control (EUI)

# %% [markdown]
# "2. +Control (EUI)": "Future_Change ~ C(Rating_Cat, Treatment(reference='0.0')) + Q('Current_EUI')"
# - Adding the baseline EUI decrease the 1-Star coefficient by over 50% (from -2.96 to -1.39), proving that the majority of the previously observed improvement could be mean reversion (inefficient buildings naturally improving). While the effect remains barely significant (p=0.035), this result shows that the fixed_effects.ipynb is biased rather than the placard having an effect.

# %%
print(list(sensitivity_list.items())[2][0])
fig, ax = plot_fixed_effects_coefficients(list(sensitivity_list.items())[2][1])
# Out:
# 3. +Control (EUI + Year)

# %% [markdown]
# "3. +Control (EUI + Year)": "Future_Change ~ C(Rating_Cat, Treatment(reference='0.0')) + Q('Current_EUI') + C(Q('Data Year'))"
# - Controlling for Data Year has 1-Star coefficient statistically insignificant (p=0.107), meaning the "Placard Effect" is not reliable for prediction. The model attributes the improvement during 2019/2020 Covid Shutdown rather than the ratings themselves.

# %%
print(list(sensitivity_list.items())[3][0])
fig, ax = plot_fixed_effects_coefficients(list(sensitivity_list.items())[3][1])
# Out:
# 4. +Control (EUI + Year + Age)

# %% [markdown]
# "4. +Control (EUI + Year + Age)": "Future_Change ~ C(Rating_Cat, Treatment(reference='0.0')) + Q('Current_EUI') + C(Q('Data Year')) + C(Q('Time Built'))"
# - Adding building age categories provides no additional explanatory power and leaves the 1-Star coefficient insignificant (p=0.132). This confirms that the failure of the model is not due to missing characteristics of the buildings. Meaning that the current approach of Linear Regression to separate the policy from the  pandemic may be wrong.
#
# This analysis validation shows that the supposed success of the Energy Rating policy in the linear model was a False Positive. Possible driven by EUI (specifically Weather Normalized Site EUI (kBtu/sq ft)) mean reversion and pandemic dropping energy usage. Since the "Star Effect" is gone when controlling for these factors, the fixed_effects.pynb methodology is not sufficent for causal inference and may be representative of something else
#
# These visualizations above shows although stars above 1.5 are show some improvement but does not show significant differences in the rate between the stars. Meaning the effects between the stars may be inconsequenial on energy usage trends.

# %%
base = (list(sensitivity_list.items())[0][1], "Base")
with_eui = (list(sensitivity_list.items())[1][1], "+EUI")
with_eui_year = (list(sensitivity_list.items())[2][1], "+EUI+DataYear")
with_eui_year_age = (list(sensitivity_list.items())[3][1], "+EUI+DataYear+BuildingAge")

all_formulas = [base, with_eui, with_eui_year, with_eui_year_age]
plot = plotting_FE_star_coef(all_formulas)

# %% [markdown]
# Base formula:
# - Dependent Variable: EUI Change
# - Independent Variable: Star Score
#
# The dependent variable is Weather Normalized Site EUI. The graph illustrates that as more building characteristics are added to the fixed effect model, the coefficients for the star ratings begin to converge. For the 1.0 and 1.5 Star ratings (the bottom two lines), the effects become statistically insignificant (indicated by grey lines, p > 0.1). Meanwhile, ratings 2.0 through 3.5 converge to a narrower positive range, while the 4-Star rating stands alone. An interpretation is that the Star Score is less of an influence on EUI and more of a reflection of three distinct building types: low-performing, mid-range, and high-performing.
#
# Example of EUI Change: The base model shows a ~6 unit difference between the coefficients for 1.5 Stars (rounded to -2.0) and 3.5 Stars (rounded to +4.0). This implies that if two identical buildings were subjected to the same conditions, the 3.5-Star building would reduce its EUI by 6 fewer units than the 1.5-Star building. However, because the coefficient for the 1.5-Star group is statistically insignificant, there is no confidence that this is a true difference and effect.
